# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/clean/airbnb_cleaned.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102058 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102058 non-null  int64
#  1   host_id                         102058 non-null  int64
#  2   host_identity_verified          102058 non-null  object
#  3   host_name                       102058 non-null  object
#  4   neighbourhood_group             102058 non-null  object
#  5   neighbourhood                   102058 non-null  object
#  6   lat                             102058 non-null  float64
#  7   long                            102058 non-null  float64
#  8   instant_bookable                102058 non-null  bool
#  9   cancellation_policy             102058 non-null  object
#  10  room_type                       102058 non-null  object
#  11  construction_year               102058 non-null  float64
# ...

# %%
data['occupancy_rate'] = 1 - (data['availability_365'] / 365)

# %%
data['occupancy_rate'].value_counts()
# Out:
# occupancy_rate
# 1.000000    23448
# 0.000000     5238
# 0.002740     1162
# 0.756164      746
# 0.997260      731
#             ...
# 1.008219       43
# 1.010959       41
# 1.027397       37
# 1.019178       36
# 1.016438       31
# Name: count, Length: 376, dtype: int64

# %%
data['fully_unavailable'] = data['availability_365'] == 0

# %%
data['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    53429
# Private room       46306
# Shared room         2208
# Hotel room           115
# Name: count, dtype: int64

# %%
data['calculated_host_listings_count'].value_counts()
# Out:
# calculated_host_listings_count
# 1.0     63440
# 2.0     14380
# 3.0      6536
# 4.0      3529
# 5.0      1977
#         ...
# 86.0       21
# 22.0       20
# 55.0       15
# 46.0        9
# 80.0        7
# Name: count, Length: 78, dtype: int64

# %%
data['host_type'] = np.where(
    data['calculated_host_listings_count'] > 1,
    'Multi-listing Host',
    'Single-listing Host'
)

# %%
data.to_csv('../data/raw/airbnb_eng.csv', index= False)
